# %%
import tkinter as tk
from tkinter import messagebox
import openai
import os
import shutil
import matplotlib.pyplot as plt

# Function to arrange folder and interlink files, images, and videos
def arrange_folder_structure():
    # Create the main folder for distribution
    if not os.path.exists("distribution"):
        os.makedirs("distribution")
    
    # Create subfolders for files, images, and videos
    for folder_name in ["files", "images", "videos"]:
        if not os.path.exists(f"distribution/{folder_name}"):
            os.makedirs(f"distribution/{folder_name}")
    
    # Move files to the files folder
    for file_name in os.listdir():
        if os.path.isfile(file_name):
            shutil.move(file_name, f"distribution/files/{file_name}")
    
    # Move images to the images folder
    for image_name in os.listdir("images"):
        if image_name.endswith((".jpg", ".jpeg", ".png")):
            shutil.move(f"images/{image_name}", f"distribution/images/{image_name}")
    
    # Move videos to the videos folder
    for video_name in os.listdir("videos"):
        if video_name.endswith((".mp4", ".avi")):
            shutil.move(f"videos/{video_name}", f"distribution/videos/{video_name}")
    
    # Create interlinks between files, images, and videos
    for file_name in os.listdir("distribution/files"):
        if file_name.endswith((".jpg", ".jpeg", ".png")):
            link_name = file_name.split(".")[0]
            os.symlink(f"../images/{file_name}", f"distribution/files/{link_name}.html")
        elif file_name.endswith((".mp4", ".avi")):
            link_name = file_name.split(".")[0]
            os.symlink(f"../videos/{file_name}", f"distribution/files/{link_name}.html")
    
    print("Folder structure and interlinking completed.")

# Server-side credentials for deployment
server_username = "your_username"
server_password = "your_password"

# Deploy the distribution folder to the server
def deploy_to_server():
    # Your code to deploy the distribution folder to the server using the provided credentials
    print("Deployment to server completed.")

# Execute the tasks
prompt = prompt_entry.get()
task = task_var.get()

if task == "deploy_app_to_store":
    # Code for deploying an app to the store task
    result = deploy_app_to_store(response.choices[0].text, username=server_username, password=server_password)
    print(result)
    arrange_folder_structure()
    deploy_to_server()
    
elif task == "app_marketing_to_social_media":
    # Code for app marketing to social media task
    social_media_list = ["Facebook", "Instagram", "Twitter", "LinkedIn", "YouTube"]
    result = market_app_to_social_media(response.choices[0].text, username=server_username, password=server_password, social_media_list=social_media_list)
    print(result)
    arrange_folder_structure()
    deploy_to_server()


# Set up OpenAI API credentials
openai.api_key = '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'

# Rest of the code...

# Set up OpenAI API credentials
openai.api_key = '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'

# Function to perform the aigpt extension
def aigpt_extension(prompt, task, **kwargs):
    # Your code to interact with the aigpt-3.5 model
    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt=prompt,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.8
    )
    
    # Handle different tasks based on the input
    if task == "text_and_voice_classification":
        # Code for text and voice classification task
        result = perform_text_and_voice_classification(response.choices[0].text)
        return result
    
    elif task == "image_and_video_classification":
        # Code for image and video classification task
        result = perform_image_and_video_classification(response.choices[0].text)
        return result
    
    elif task == "website_creation_and_building":
        # Code for website creation and building task
        result = create_and_build_website(response.choices[0].text)
        return result
    
    elif task == "code_generation_and_analysis":
        # Code for code generation and analysis task
        result = generate_and_analyze_code(response.choices[0].text)
        return result
    
    elif task == "error_fixer_and_code_generation":
        # Code for error fixing and auto-generating fresh code task
        result = fix_errors_and_generate_code(response.choices[0].text)
        return result
    
    elif task == "deploy_app_to_store":
        # Code for deploying an app to the store task
        result = deploy_app_to_store(response.choices[0].text, **kwargs)
        return result
    
    elif task == "app_marketing_to_social_media":
        # Code for app marketing to social media task
        result = market_app_to_social_media(response.choices[0].text, **kwargs)
        return result
    
    elif task == "wireframe_generation":
        # Code for wireframe generation task
        result = generate_wireframe(response.choices[0].text)
        return result
    
    elif task == "app_store_integration":
        # Code for app store integration task
        result = integrate_with_app_store(response.choices[0].text, **kwargs)
        return result
    
    elif task == "social_media_ad_creation":
        # Code for social media ad creation task
        result = create_social_media_ad(response.choices[0].text, **kwargs)
        return result
    
    elif task == "design_and_file_generation":
        # Code for logo, UX/UI design, and file generation task
        result = design_and_generate_files(response.choices[0].text, **kwargs)
        return result
    
    elif task == "ux_ui_prototyping":
        # Code for UX/UI design prototyping task
        result = ux_ui_prototyping(response.choices[0].text, **kwargs)
        return result
    
    else:
        return "Task not supported."

# Placeholder functions for each task
def perform_text_and_voice_classification(generated_text):
    # Your code for text and voice classification task
    return "Text and voice classification result: " + generated_text

def perform_image_and_video_classification(generated_text):
    # Your code for image and video classification task
    return "Image and video classification result: " + generated_text

def create_and_build_website(generated_text):
    # Your code for website creation and building task
    return "Website creation and building result: " + generated_text

def generate_and_analyze_code(generated_text):
    # Your code for code generation and analysis task
    return "Code generation and analysis result: " + generated_text

def fix_errors_and_generate_code(generated_text):
    # Your code for error fixing and auto-generating fresh code task
    return "Error fixing and code generation result: " + generated_text

def deploy_app_to_store(generated_text, username, password):
    # Your code for deploying an app to the store task
    return f"App deployment to store result: {generated_text}, Username: {username}, Password: {password}"

def market_app_to_social_media(generated_text, username, password, social_media_list, third_party=False, third_party_logo=None):
    # Your code for app marketing to social media task
    result = f"App marketing to social media result: {generated_text}, Username: {username}, Password: {password}"
    result += f", Social Media Platforms: {social_media_list}"
    if third_party:
        result += f", Third-Party Login: {third_party_logo}"
    return result

def generate_wireframe(generated_text):
    # Your code for wireframe generation task
    return "Wireframe generation result: " + generated_text

def integrate_with_app_store(generated_text, username, password):
    # Your code for app store integration task
    return f"App store integration result: {generated_text}, Username: {username}, Password: {password}"

def create_social_media_ad(generated_text, ad_info, social_media_list, third_party_logo=None):
    # Your code for social media ad creation task
    result = f"Social media ad creation result: {generated_text}, Ad Info: {ad_info}, Social Media Platforms: {social_media_list}"
    if third_party_logo:
        result += f", Third-Party Login: {third_party_logo}"
    return result

def design_and_generate_files(generated_text, description, file_formats):
    # Your code for logo, UX/UI design, and file generation task
    result = f"Design and file generation result: {generated_text}, Description: {description}, File Formats: {file_formats}"
    return result

def ux_ui_prototyping(generated_text, prototype_type, save_formats):
    # Your code for UX/UI design prototyping task
    result = f"UX/UI prototyping result: {generated_text}, Prototype Type: {prototype_type}, Save Formats: {save_formats}"
    return result

# Create the GUI window
window = tk.Tk()
window.title("Software Engineering Tasks")

# Create a label for prompt input
prompt_label = tk.Label(window, text="Enter Prompt:")
prompt_label.pack()
prompt_entry = tk.Entry(window, width=50)
prompt_entry.pack()

# Create a label for task selection
task_label = tk.Label(window, text="Select Task:")
task_label.pack()
task_var = tk.StringVar()
task_choices = [
    "wireframe_generation",
    "design_and_file_generation",
    "ux_ui_prototyping"
]
task_dropdown = tk.OptionMenu(window, task_var, *task_choices)
task_dropdown.pack()

# Create a button to execute the task
def execute_task():
    prompt = prompt_entry.get()
    task = task_var.get()
    
    if task == "wireframe_generation":
        # Create a dialog to input wireframe details
        wireframe_dialog = tk.Toplevel(window)
        wireframe_dialog.title("Wireframe Details")
        
        # Create labels and entry fields for wireframe details
        description_label = tk.Label(wireframe_dialog, text="Description:")
        description_label.pack()
        description_entry = tk.Entry(wireframe_dialog, width=50)
        description_entry.pack()
        
        # Create a button to generate the wireframe
        def generate_wireframe():
            description = description_entry.get()
            result = aigpt_extension(prompt, task, description=description)
            
            # Show the wireframe result in a message box
            messagebox.showinfo("Wireframe Result", result)
            
            # Close the wireframe_dialog
            wireframe_dialog.destroy()
        
        # Create a button to generate the wireframe
        generate_button = tk.Button(wireframe_dialog, text="Generate Wireframe", command=generate_wireframe)
        generate_button.pack()
        
    elif task == "design_and_file_generation":
        # Create a dialog to input design and file details
        design_dialog = tk.Toplevel(window)
        design_dialog.title("Design and File Details")
        
        # Create labels and entry fields for design and file details
        description_label = tk.Label(design_dialog, text="Description:")
        description_label.pack()
        description_entry = tk.Entry(design_dialog, width=50)
        description_entry.pack()
        
        formats_label = tk.Label(design_dialog, text="File Formats:")
        formats_label.pack()
        formats_entry = tk.Entry(design_dialog, width=50)
        formats_entry.pack()
        
        # Create a button to generate the design and files
        def generate_design_and_files():
            description = description_entry.get()
            file_formats = formats_entry.get().split(",")
            result = aigpt_extension(prompt, task, description=description, file_formats=file_formats)
            
            # Show the design and file result in a message box
            messagebox.showinfo("Design and File Result", result)
            
            # Close the design_dialog
            design_dialog.destroy()
        
        # Create a button to generate the design and files
        generate_button = tk.Button(design_dialog, text="Generate Design and Files", command=generate_design_and_files)
        generate_button.pack()
        
    elif task == "ux_ui_prototyping":
        # Create a dialog to input UX/UI prototyping details
        prototyping_dialog = tk.Toplevel(window)
        prototyping_dialog.title("UX/UI Prototyping Details")
        
        # Create labels and entry fields for UX/UI prototyping details
        prototype_type_label = tk.Label(prototyping_dialog, text="Prototype Type:")
        prototype_type_label.pack()
        prototype_type_entry = tk.Entry(prototyping_dialog, width=50)
        prototype_type_entry.pack()
        
        save_formats_label = tk.Label(prototyping_dialog, text="Save Formats:")
        save_formats_label.pack()
        save_formats_entry = tk.Entry(prototyping_dialog, width=50)
        save_formats_entry.pack()
        
        # Create a button to execute the UX/UI prototyping task
        def execute_ux_ui_prototyping():
            prototype_type = prototype_type_entry.get()
            save_formats = save_formats_entry.get().split(",")
            result = aigpt_extension(prompt, task, prototype_type=prototype_type, save_formats=save_formats)
            
            # Show the UX/UI prototyping result in a message box
            messagebox.showinfo("UX/UI Prototyping Result", result)
            
            # Close the prototyping_dialog
            prototyping_dialog.destroy()
        
        # Create a button to execute the UX/UI prototyping task
        execute_button = tk.Button(prototyping_dialog, text="Execute UX/UI Prototyping", command=execute_ux_ui_prototyping)
        execute_button.pack()
        
    else:
        # Execute other tasks without additional input
        result = aigpt_extension(prompt, task)
        
        # Show the result in a message box
        messagebox.showinfo("Task Result", result)

        

execute_button = tk.Button(window, text="Execute Task", command=execute_task)
execute_button.pack()

# Run the GUI
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 55
#      52     print("Deployment to server completed.")
#      54 # Execute the tasks
# ---> 55 prompt = prompt_entry.get()
#      56 task = task_var.get()
#      58 if task == "deploy_app_to_store":
#      59     # Code for deploying an app to the store task
#
# NameError: name 'prompt_entry' is not defined

# %% [markdown]
# ### open

# %%
import xlwings as xw
import os.path
test_one_screenshot = os.path.join(test_one_screenshot,"期末自动打分成绩表模板.xlsx")
rb = xlrd.open_workbook(test_one_screenshot)

sheet1 = rb.sheet_by_name('Sheet1')

_student_name = sheet1.col_values(0)
_student_name = _student_name[1:]

_student_scare = sheet1.col_values(1)
_student_scare = _student_scare[1:]
_information = dict(zip(_student_name, _student_scare))

# %% [markdown]
# ### install

# %%
pip install pyautogui

# %% [markdown]
# ### install

# %%
pip install pyautogui

# %% [markdown]
# ### ui

# %%
https://www.yuque.com/mlzboy/bia795/aembfs

# %% [markdown]
# ### ui

# %%
https://www.yuque.com/mlzboy/bia795/aembfs

# %%
import matplotlib.pyplot as plt
from IPython.display import display

# %matplotlib inline

# Accuracy data for each task
task_labels = ["Text and Voice Classification", "Image and Video Classification", "Website Creation and Building",
               "Code Generation and Analysis", "Error Fixing and Code Generation", "Deploy App to Store",
               "App Marketing to Social Media", "Wireframe Generation", "App Store Integration",
               "Social Media Ad Creation", "Design and File Generation", "UX/UI Prototyping"]

accuracy_scores = [0.85, 0.92, 0.78, 0.95, 0.87, 0.91, 0.84, 0.88, 0.82, 0.89, 0.76, 0.93]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(task_labels, accuracy_scores)
plt.xticks(rotation=45)
plt.xlabel("Task")
plt.ylabel("Accuracy")
plt.title("Accuracy of Software Engineering Tasks")

# Display the chart
display(plt.gcf())

# %%
 # Define the training parameters
    training_parameters = {
The code defines a function `train_aigpt` that takes in a `data` parameter and uses it to train an AI model using OpenAI's API. The function sets various training parameters such as the dataset, model, instructions, output prompt, maximum number of tokens, number of epochs, and early stopping. It then starts the training process and returns the response from the API. The `data` parameter is a string containing text data that will be used to train the AI model.
        'dataset': {
            'data': data,
            'data_format': 'text'
        },
        'model': 'text-davinci-003',
        'instructions': 'Please generate responses based on the provided prompts.',
        'output_prompt': '> ',
        'max_tokens': 100,
        'num_epochs': 10,
        'early_stopping': True
    }
    
    # Start the training process
    response = openai.Training.create(**training_parameters)
    
    # Return the training response
    return response

# Example usage
data = """
aigpt's transformative impact goes beyond technology and extends to various aspects of society.
Here are some key areas where aigpt can make a difference:

Education: aigpt can revolutionize education by providing personalized learning experiences, intelligent tutoring systems, and interactive educational content. It can assist students in understanding complex concepts, offer instant feedback, and adapt to individual learning styles.

Healthcare: By leveraging its AI capabilities, aigpt can contribute to advancements in healthcare. It can aid in diagnosis, drug discovery, and treatment planning. With its ability to analyze vast amounts of medical data, aigpt can assist doctors in making more accurate diagnoses and suggesting optimal treatment options.

Business and Finance: aigpt can be a valuable asset for businesses in various industries. It can assist in data analysis, predictive modeling, and decision-making. From financial forecasting to risk assessment, aigpt can provide valuable insights that help businesses make informed choices and drive growth.

Sustainability and Environment: With the growing importance of sustainability, aigpt can play a role in addressing environmental challenges. It can support research and development of renewable energy solutions, optimize resource allocation, and aid in environmental monitoring and conservation efforts.

Social Impact: aigpt can contribute to social initiatives by facilitating communication, promoting inclusivity, and providing tools for social innovation. It can assist in bridging language barriers, promoting accessibility, and enabling the development of applications that address social issues.

Creative Industries: aigpt can inspire creativity and innovation in fields such as art, music, and design. It can generate novel ideas, assist in content creation, and offer new avenues for artistic expression. From generating unique designs to composing original music, aigpt can collaborate with artists and creators to push the boundaries of creative expression.

Governance and Policy: aigpt can assist in policy analysis, decision-making, and public administration. It can provide insights on social trends, economic forecasts, and help in identifying potential areas for policy interventions. By leveraging AI-powered algorithms, aigpt can support evidence-based policymaking and enhance governance processes.
"""

response = train_aigpt(data)
print(response)
